# %%
from tkinter import *

def q1(a,b):
    ast=0
    bs=0
    for i in str(a):
        ast+=int(i)
    for i in str(b):
        bs+=int(i)
    return ast+bs

def q2(a,b):
    return a**b


def q3(a,b):
    from primesieve import primes
    temp=0
    if a>=b:
        pass
    elif a<b:
        temp=a
        a=b
        b=temp
    alist=[]
    blist=[]
    for i in primes(a):
        count=0
        while a%i==0:
            count+=1
            a=int(a/i)
        if count!=0:
            alist.append((i,count))
        if a==1:
            break
    for i in primes(b):
        count=0
        while b%i==0:
            count+=1
            b=int(b/i)
        if count!=0:
            blist.append((i,count))
        if b==1:
            break
    ast=''
    bst=''
    if alist==[]:
        ast=str(a)
    else:
        for i in alist:
            ast+=str(i[0])
            ast+=str(i[1])
    if blist==[]:
        bst=str(b)
    else:
        for i in blist:
            bst+=str(i[0])
            bst+=str(i[1])
    return int(ast+bst)
    
    
def q4(a,b):
    temp=0
    if a>=b:
        pass
    elif a<b:
        temp=a
        a=b
        b=temp
    p={'0':1,'6':1,'8':2,'9':1}
    a=str(a)
    b=str(b)
    ast=0
    bs=0
    for i in a:
        if i in p:
            ast+=p[i]
    for i in b:
        if i in p:
            bs+=p[i]
    return int(str(ast)+str(bs))


def q5(a,b):
    s=a+b
    dig=1
    while s//(10**(dig-1))!=0:
        dig+=1
    orig=0
    for i in range(dig-1):
        orig+=9*(10**i)
    return orig-s


def q6(a,b):
    import primesieve
    temp=0
    if a>=b:
        pass
    elif a<b:
        temp=a
        a=b
        b=temp
    cnt=len(primesieve.primes(b,a))
    if b in primesieve.primes(b,a):
        cnt-=1
    if a in primesieve.primes(b,a):
        cnt-=1
    return cnt


def q7(a,b):
    return (a+b)%12


def get11(event):
        global hint11
        hint11=int(input11.get())

def get12(event):
    global hint12,hint11,qnum,qlist
    hint12=int(input12.get())
    label11.config(text="="+str(qlist[qnum](hint11,hint12)))

def get21(event):
    global hint21
    hint21=int(input21.get())

def get22(event):
    global hint22,hint21,qnum,qlist
    hint22=int(input22.get())
    label21.config(text="="+str(qlist[qnum](hint21,hint22)))

def get31(event):
    global hint31
    hint31=int(input31.get())

def get32(event):
    global hint32,hint31,qnum,qlist
    hint32=int(input32.get())
    label31.config(text="="+str(qlist[qnum](hint31,hint32)))

def get41(event):
    global hint11
    hint41=int(input41.get())

def get42(event):
    global hint42,hint41,qnum,qlist
    hint42=int(input42.get())
    label41.config(text="="+str(qlist[qnum](hint41,hint42)))

def get51(event):
    global hint51
    hint51=int(input51.get())

def get52(event):
    global hint52,hint51,qnum,qlist
    hint52=int(input52.get())
    label51.config(text="="+str(qlist[qnum](hint51,hint52)))

def get61(event):
    global hint61
    hint61=int(input61.get())

    
def get62(event):
    global hint62,hint61,qnum,qlist
    hint62=int(input62.get())
    label61.config(text="="+str(qlist[qnum](hint61,hint62)))


def get71(event):
    global hint71
    hint71=int(input71.get())

def get72(event):
    global hint72,hint71,qnum,qlist
    hint72=int(input72.get())
    label71.config(text="="+str(qlist[qnum](hint71,hint72)))

def get81(event):
    global hint81
    hint81=int(input81.get())

def get82(event):
    global hint82,hint81,qnum,qlist
    hint82=int(input82.get())
    label81.config(text="="+str(qlist[qnum](hint81,hint82)))

def getans(event):
    global question,qnum
    if int(ans.get())==qlist[qnum](question[qnum][0],question[qnum][1]):
        label0.config(text='   정답')
        window.destroy()
    else:
        label0.config(text='   오답')



question=[(3,4),(4,3),(16,48),(25,131),(2,7),(4,21),(4,5)]

qlist=[q1,q2,q3,q4,q5,q6,q7]
qnum=0
hint11=0
hint12=0
hint21=0
hint22=0
hint31=0
hint32=0
hint41=0
hint42=0
hint51=0
hint52=0
hint61=0
hint62=0
hint71=0
hint72=0
hint81=0
hint82=0



for i in range(7):
    hint11=0
    hint12=0
    hint21=0
    hint22=0
    hint31=0
    hint32=0
    hint41=0
    hint42=0
    hint51=0
    hint52=0
    hint61=0
    hint62=0
    hint71=0
    hint72=0
    hint81=0
    hint82=0
    qnum=i
    window=Tk()

    window.title("미스터리 사인"+' Q'+str(qnum+1))
    window.geometry("{0}x{1}+0+0".format(window.winfo_screenwidth(), window.winfo_screenheight()))

    window.resizable(True,True)

    quest1=Label(window,text=str(question[qnum][0])+'?'+str(question[qnum][1])+'=')
    quest1.grid(row=0,column=4)
    ans=Entry(window,width=30)
    ans.bind("<Return>",getans)
    ans.grid(row=0,column=5)
    label0=Label(window)
    label0.grid(row=0,column=6)
    input11=Entry(window,width=30)
    input11.bind("<Return>",get11)
    input11.grid(row=1,column=0)
    input12=Entry(window,width=30)
    input12.grid(row=1,column=2)
    input12.bind("<Return>",get12)
    label1=Label(window,text='?',width=10,height=5)
    label1.grid(row=1,column=1)
    label11=Label(window,text='=',width=10,height=5)
    label11.grid(row=1,column=3)
    space1=Label(window,width=10,height=5)
    space1.grid(row=1,column=4)
    input21=Entry(window,width=30)
    input21.bind("<Return>",get21)
    input21.grid(row=1,column=5)
    input22=Entry(window,width=30)
    input22.grid(row=1,column=7)
    input22.bind("<Return>",get22)
    label2=Label(window,text='?',width=10,height=5)
    label2.grid(row=1,column=6)
    label21=Label(window,text='=',width=10,height=5)
    label21.grid(row=1,column=8)
    space2=Label(window,width=10,height=5)
    space2.grid(row=1,column=9)
    input31=Entry(window,width=30)
    input31.bind("<Return>",get31)
    input31.grid(row=2,column=0)
    input32=Entry(window,width=30)
    input32.grid(row=2,column=2)
    input32.bind("<Return>",get32)
    label3=Label(window,text='?',width=10,height=5)
    label3.grid(row=2,column=1)
    label31=Label(window,text='=',width=10,height=5)
    label31.grid(row=2,column=3)
    space3=Label(window,width=10,height=5)
    space3.grid(row=2,column=4)
    input41=Entry(window,width=30)
    input41.bind("<Return>",get41)
    input41.grid(row=2,column=5)
    input42=Entry(window,width=30)
    input42.grid(row=2,column=7)
    input42.bind("<Return>",get42)
    label4=Label(window,text='?',width=10,height=5)
    label4.grid(row=2,column=6)
    label41=Label(window,text='=',width=10,height=5)
    label41.grid(row=2,column=8)
    space4=Label(window,width=10,height=5)
    space4.grid(row=2,column=9)
    input51=Entry(window,width=30)
    input51.bind("<Return>",get51)
    input51.grid(row=3,column=0)
    input52=Entry(window,width=30)
    input52.grid(row=3,column=2)
    input52.bind("<Return>",get52)
    label5=Label(window,text='?',width=10,height=5)
    label5.grid(row=3,column=1)
    label51=Label(window,text='=',width=10,height=5)
    label51.grid(row=3,column=3)
    space5=Label(window,width=10,height=5)
    space5.grid(row=3,column=4)
    input61=Entry(window,width=30)
    input61.bind("<Return>",get61)
    input61.grid(row=3,column=5)
    input62=Entry(window,width=30)
    input62.grid(row=3,column=7)
    input62.bind("<Return>",get62)
    label6=Label(window,text='?',width=10,height=5)
    label6.grid(row=3,column=6)
    label61=Label(window,text='=',width=10,height=5)
    label61.grid(row=3,column=8)
    space6=Label(window,width=10,height=5)
    space6.grid(row=3,column=9)
    input71=Entry(window,width=30)
    input71.bind("<Return>",get71)
    input71.grid(row=4,column=0)
    input72=Entry(window,width=30)
    input72.grid(row=4,column=2)
    input72.bind("<Return>",get72)
    label7=Label(window,text='?',width=10,height=5)
    label7.grid(row=4,column=1)
    label71=Label(window,text='=',width=10,height=5)
    label71.grid(row=4,column=3)
    space7=Label(window,width=10,height=5)
    space7.grid(row=4,column=4)
    input81=Entry(window,width=30)
    input81.bind("<Return>",get81)
    input81.grid(row=4,column=5)
    input82=Entry(window,width=30)
    input82.grid(row=4,column=7)
    input82.bind("<Return>",get82)
    label8=Label(window,text='?',width=10,height=5)
    label8.grid(row=4,column=6)
    label81=Label(window,text='=',width=10,height=5)
    label81.grid(row=4,column=8)
    space8=Label(window,width=10,height=5)
    space8.grid(row=4,column=9)
    window.mainloop()
# Out:
# adga
